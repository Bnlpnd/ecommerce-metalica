# %%
import pandas as pd
# Cargar el archivo
df = pd.read_csv("datajupiter.csv")

# Mostrar las primeras filas
df.head()
# Out:
#    idCotizacion  tipo  product  material  alto  ancho  precioCotizacion
# 0             1     1        1         1   250     90               300
# 1             2     1        1         1   249     90               300
# 2             3     1        1         1   251     90               300
# 3             4     1        1         1   250     91               300
# 4             5     1        1         1   251     93               300

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.2.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached numpy-2.2.5-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# -------------------------------------------------------------------------
# ModuleNotFoundError                     Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       2 from sklearn.preprocessing import StandardScaler
#       3 from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import pandas as pd

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
from sklearn.feature_selection import SelectFromModel

# %%
# Cargar el archivo
df = pd.read_csv("datajupiter.csv")

# %%
# Mostrar las primeras filas
df.head()
# Out:
#    idCotizacion  tipo  product  material  alto  ancho  precioCotizacion
# 0             1     1        1         1   250     90               300
# 1             2     1        1         1   249     90               300
# 2             3     1        1         1   251     90               300
# 3             4     1        1         1   250     91               300
# 4             5     1        1         1   251     93               300

# %%
# Información general: tipos de datos, nulos, etc.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   idCotizacion      350 non-null    int64
#  1   tipo              350 non-null    int64
#  2   product           350 non-null    int64
#  3   material          350 non-null    int64
#  4   alto              350 non-null    int64
#  5   ancho             350 non-null    int64
#  6   precioCotizacion  350 non-null    int64
# dtypes: int64(7)
# memory usage: 19.3 KB

# %%
# Conteo de valores únicos por columna
df.nunique()
# Out:
# idCotizacion        350
# tipo                  7
# product              12
# material              3
# alto                 52
# ancho                29
# precioCotizacion     48
# dtype: int64

# %%
# !pip install matplotlib seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/104.6 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/104.6 kB ? eta -:--:--
#      ---------- -------------------------- 30.7/104.6 kB 445.2 kB/s eta 0:00:01
#      -------------- ---------------------- 41.0/104.6 kB 330.3 kB/s eta 0:00:01
#      --------------------- --------------- 61.4/104.6 kB 365.7 kB/s eta 0:00:01
#      -------------------------------- ---- 92.2/104.6 kB 438.1 kB/s eta 0:00:01
#      ------------------------------------ 104.6/104.6 kB 403.3 kB/s eta 0:00:00
# ...
#   Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB 653.6 kB/s eta 0:00:13
#    ---------------------------------------- 0.1/8.1 MB 656.4 kB/s eta 0:00:13
# ...

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['precioCotizacion'], kde=True, bins=20)
plt.title('Distribución del Precio de Cotización')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='ancho', y='alto', hue='precioCotizacion', palette='viridis')
plt.title('Relación entre Alto, Ancho y Precio')
plt.xlabel('Ancho')
plt.ylabel('Alto')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 5))

sns.boxplot(data=df, x='tipo', y='precioCotizacion', ax=axs[0])
axs[0].set_title('Precio según Tipo')

sns.boxplot(data=df, x='product', y='precioCotizacion', ax=axs[1])
axs[1].set_title('Precio según Producto')

sns.boxplot(data=df, x='material', y='precioCotizacion', ax=axs[2])
axs[2].set_title('Precio según Material')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['alto'], df['ancho'], df['precioCotizacion'], c=df['precioCotizacion'], cmap='viridis')
ax.set_xlabel('Alto')
ax.set_ylabel('Ancho')
ax.set_zlabel('Precio Cotización')
ax.set_title('Alto vs Ancho vs Precio (3D)')
plt.show()
